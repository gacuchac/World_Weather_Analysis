# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

import requests
import gmaps

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

import sys
sys.path.append('../')
# Import the API key.
from config import weather_api_key, g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

cities_appended = 0

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.q
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_info = {"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date}
        # Append the city information into city_data list.
        city_data.append(city_info)

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | sarahan
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | port hedland
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | nome
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | borinskoye
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | mumford
# Processing Record 16 of Set 1 | kalach-na-donu
# Processing Record 17 of Set 1 | taiyuan
# Processing Record 18 of Set 1 | catamarca
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | kaohsiung
# Processing Record 21 of Set 1 | ganzhou
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | kaeng khlo
# City not found. Skipping...
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | lompoc
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | hasaki
# Processing Record 36 of Set 1 | panaba
# Processing Record 37 of Set 1 | riyadh
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | maceio
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 1 | laguna
# Processing Record 44 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | la rioja
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | oktyabrskiy
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | benghazi
# Processing Record 3 of Set 2 | samarai
# Processing Record 4 of Set 2 | muroto
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | esna
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | yamada
# Processing Record 11 of Set 2 | mecca
# Processing Record 12 of Set 2 | kubinka
# Processing Record 13 of Set 2 | tual
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | chapais
# Processing Record 17 of Set 2 | anadyr
# Processing Record 18 of Set 2 | salinopolis
# Processing Record 19 of Set 2 | vestmannaeyjar
# Processing Record 20 of Set 2 | villa bruzual
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | acarau
# Processing Record 26 of Set 2 | caravelas
# Processing Record 27 of Set 2 | oranjemund
# Processing Record 28 of Set 2 | okha
# Processing Record 29 of Set 2 | mayumba
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | rawson
# Processing Record 33 of Set 2 | san lazaro
# Processing Record 34 of Set 2 | magnolia
# Processing Record 35 of Set 2 | gurupi
# Processing Record 36 of Set 2 | chakulia
# Processing Record 37 of Set 2 | nepomuk
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | ayagoz
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | fairbanks
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | wewak
# Processing Record 44 of Set 2 | elko
# Processing Record 45 of Set 2 | puerto escondido
# Processing Record 46 of Set 2 | jurado
# Processing Record 47 of Set 2 | seoul
# Processing Record 48 of Set 2 | tilichiki
# Processing Record 49 of Set 2 | gazli
# Processing Record 50 of Set 2 | carauari
# Processing Record 1 of Set 3 | arlit
# Processing Record 2 of Set 3 | jashpurnagar
# Processing Record 3 of Set 3 | sukhovolya
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | forrest city
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | san patricio
# Processing Record 8 of Set 3 | port antonio
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | bubaque
# Processing Record 12 of Set 3 | montrose
# Processing Record 13 of Set 3 | fortuna
# Processing Record 14 of Set 3 | rio cuarto
# Processing Record 15 of Set 3 | aykhal
# Processing Record 16 of Set 3 | kisangani
# Processing Record 17 of Set 3 | longyan
# Processing Record 18 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 3 | tahlequah
# Processing Record 20 of Set 3 | quesnel
# Processing Record 21 of Set 3 | karratha
# Processing Record 22 of Set 3 | ketchikan
# Processing Record 23 of Set 3 | maneadero
# Processing Record 24 of Set 3 | port blair
# Processing Record 25 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 3 | bandarbeyla
# Processing Record 27 of Set 3 | san quintin
# Processing Record 28 of Set 3 | clyde river
# Processing Record 29 of Set 3 | faya
# Processing Record 30 of Set 3 | timra
# Processing Record 31 of Set 3 | wetaskiwin
# Processing Record 32 of Set 3 | burica
# City not found. Skipping...
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | ahipara
# Processing Record 35 of Set 3 | alnavar
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | meulaboh
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | parainen
# Processing Record 42 of Set 3 | taseyevo
# Processing Record 43 of Set 3 | barcelos
# Processing Record 44 of Set 3 | sao filipe
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | mastic beach
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | vila franca do campo
# Processing Record 49 of Set 3 | klaksvik
# Processing Record 50 of Set 3 | parrita
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | nouadhibou
# Processing Record 3 of Set 4 | galle
# Processing Record 4 of Set 4 | chicama
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | pinega
# Processing Record 8 of Set 4 | taltal
# Processing Record 9 of Set 4 | olafsvik
# Processing Record 10 of Set 4 | mokhsogollokh
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | tommot
# Processing Record 13 of Set 4 | constitucion
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | onguday
# Processing Record 17 of Set 4 | tahoua
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | boende
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | conde
# Processing Record 23 of Set 4 | huarmey
# Processing Record 24 of Set 4 | abong mbang
# Processing Record 25 of Set 4 | nemuro
# Processing Record 26 of Set 4 | fryanovo
# Processing Record 27 of Set 4 | chizhou
# Processing Record 28 of Set 4 | togur
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | north bend
# Processing Record 31 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 4 | honiara
# Processing Record 33 of Set 4 | ust-tsilma
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | zhangye
# Processing Record 36 of Set 4 | san cristobal
# Processing Record 37 of Set 4 | hofn
# Processing Record 38 of Set 4 | mount gambier
# Processing Record 39 of Set 4 | nioro
# Processing Record 40 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 4 | zamora
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | westport
# Processing Record 44 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | la ronge
# Processing Record 47 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 4 | beloha
# Processing Record 49 of Set 4 | rypefjord
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | vanimo
# Processing Record 2 of Set 5 | port keats
# Processing Record 3 of Set 5 | jacksonville
# Processing Record 4 of Set 5 | rudbar
# Processing Record 5 of Set 5 | stribro
# Processing Record 6 of Set 5 | half moon bay
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 5 | santa isabel do rio negro
# Processing Record 10 of Set 5 | old town
# Processing Record 11 of Set 5 | olinda
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | okhotsk
# Processing Record 14 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 5 | te anau
# Processing Record 16 of Set 5 | sola
# Processing Record 17 of Set 5 | saint-pierre
# Processing Record 18 of Set 5 | kodinsk
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | chute-aux-outardes
# Processing Record 21 of Set 5 | verkhnevilyuysk
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | zhuhai
# Processing Record 24 of Set 5 | quelimane
# Processing Record 25 of Set 5 | fukue
# Processing Record 26 of Set 5 | lavrentiya
# Processing Record 27 of Set 5 | sept-iles
# Processing Record 28 of Set 5 | hatillo
# Processing Record 29 of Set 5 | yerbogachen
# Processing Record 30 of Set 5 | kokoda
# Processing Record 31 of Set 5 | domokos
# Processing Record 32 of Set 5 | eenhana
# Processing Record 33 of Set 5 | yellowknife
# Processing Record 34 of Set 5 | rexburg
# Processing Record 35 of Set 5 | corralillo
# Processing Record 36 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 5 | sitka
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 5 | celestun
# Processing Record 43 of Set 5 | sao joao da barra
# Processing Record 44 of Set 5 | lingao
# Processing Record 45 of Set 5 | tateyama
# Processing Record 46 of Set 5 | ostrovnoy
# Processing Record 47 of Set 5 | sile
# Processing Record 48 of Set 5 | tura
# Processing Record 49 of Set 5 | impfondo
# Processing Record 50 of Set 5 | naryan-mar
# Processing Record 1 of Set 6 | kaduqli
# Processing Record 2 of Set 6 | kruisfontein
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | sao desiderio
# Processing Record 5 of Set 6 | port augusta
# Processing Record 6 of Set 6 | alghero
# Processing Record 7 of Set 6 | fare
# Processing Record 8 of Set 6 | boguchany
# Processing Record 9 of Set 6 | klyuchi
# Processing Record 10 of Set 6 | bardiyah
# Processing Record 11 of Set 6 | nouakchott
# Processing Record 12 of Set 6 | high level
# Processing Record 13 of Set 6 | waipawa
# Processing Record 14 of Set 6 | covington
# Processing Record 15 of Set 6 | gizo
# Processing Record 16 of Set 6 | yulara
# Processing Record 17 of Set 6 | evensk
# Processing Record 18 of Set 6 | mayor pablo lagerenza
# Processing Record 19 of Set 6 | tiksi
# Processing Record 20 of Set 6 | batagay
# Processing Record 21 of Set 6 | norman wells
# Processing Record 22 of Set 6 | krasnoselkup
# Processing Record 23 of Set 6 | minab
# Processing Record 24 of Set 6 | kedrovyy
# Processing Record 25 of Set 6 | nipawin
# Processing Record 26 of Set 6 | zyryanka
# Processing Record 27 of Set 6 | darlawn
# Processing Record 28 of Set 6 | vila velha
# Processing Record 29 of Set 6 | islampur
# Processing Record 30 of Set 6 | pevek
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | jinchang
# Processing Record 33 of Set 6 | juneau
# Processing Record 34 of Set 6 | saint anthony
# Processing Record 35 of Set 6 | mountain home
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | marawi
# Processing Record 38 of Set 6 | mackay
# Processing Record 39 of Set 6 | kolyshley
# Processing Record 40 of Set 6 | kimbe
# Processing Record 41 of Set 6 | ponta do sol
# Processing Record 42 of Set 6 | uyar
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | rudnichnyy
# Processing Record 45 of Set 6 | palimbang
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | avera
# Processing Record 48 of Set 6 | teya
# Processing Record 49 of Set 6 | san luis jilotepeque
# Processing Record 50 of Set 6 | hukuntsi
# Processing Record 1 of Set 7 | gazojak
# Processing Record 2 of Set 7 | tambura
# Processing Record 3 of Set 7 | nizhniy kuranakh
# Processing Record 4 of Set 7 | kysyl-syr
# Processing Record 5 of Set 7 | cherat
# Processing Record 6 of Set 7 | evans
# Processing Record 7 of Set 7 | great falls
# Processing Record 8 of Set 7 | nicolas bravo
# Processing Record 9 of Set 7 | torbay
# Processing Record 10 of Set 7 | north battleford
# Processing Record 11 of Set 7 | wonthaggi
# Processing Record 12 of Set 7 | goderich
# Processing Record 13 of Set 7 | jasper
# Processing Record 14 of Set 7 | kant
# Processing Record 15 of Set 7 | yei
# Processing Record 16 of Set 7 | muros
# Processing Record 17 of Set 7 | pareora
# Processing Record 18 of Set 7 | nanortalik
# Processing Record 19 of Set 7 | byron bay
# Processing Record 20 of Set 7 | tomatlan
# Processing Record 21 of Set 7 | santa fe
# Processing Record 22 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 7 | nikolskoye
# Processing Record 24 of Set 7 | souillac
# Processing Record 25 of Set 7 | namatanai
# Processing Record 26 of Set 7 | talnakh
# Processing Record 27 of Set 7 | artyom
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | fereydun kenar
# Processing Record 30 of Set 7 | sendenhorst
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | aksu
# Processing Record 33 of Set 7 | port lincoln
# Processing Record 34 of Set 7 | dmitriyevskoye
# Processing Record 35 of Set 7 | voh
# Processing Record 36 of Set 7 | mackenzie
# Processing Record 37 of Set 7 | zhmerynka
# Processing Record 38 of Set 7 | marsh harbour
# Processing Record 39 of Set 7 | anuradhapura
# Processing Record 40 of Set 7 | amapa
# Processing Record 41 of Set 7 | price
# Processing Record 42 of Set 7 | kalaleh
# Processing Record 43 of Set 7 | charters towers
# Processing Record 44 of Set 7 | new amsterdam
# Processing Record 45 of Set 7 | miles city
# Processing Record 46 of Set 7 | port hardy
# Processing Record 47 of Set 7 | ulaangom
# Processing Record 48 of Set 7 | octeville
# Processing Record 49 of Set 7 | kariba
# Processing Record 50 of Set 7 | walvis bay
# Processing Record 1 of Set 8 | ballina
# Processing Record 2 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 8 | starokozache
# Processing Record 4 of Set 8 | rongcheng
# Processing Record 5 of Set 8 | cam ranh
# Processing Record 6 of Set 8 | severo-kurilsk
# Processing Record 7 of Set 8 | bairiki
# Processing Record 8 of Set 8 | makat
# Processing Record 9 of Set 8 | upernavik
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | marfino
# Processing Record 12 of Set 8 | staffanstorp
# Processing Record 13 of Set 8 | gediz
# Processing Record 14 of Set 8 | alice springs
# Processing Record 15 of Set 8 | kot kapura
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | abnub
# Processing Record 18 of Set 8 | andenes
# Processing Record 19 of Set 8 | pirapozinho
# Processing Record 20 of Set 8 | adrar
# Processing Record 21 of Set 8 | agbor
# Processing Record 22 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 8 | port-gentil
# Processing Record 24 of Set 8 | strezhevoy
# Processing Record 25 of Set 8 | hervey bay
# Processing Record 26 of Set 8 | matagami
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | sayat
# Processing Record 30 of Set 8 | mingshui
# Processing Record 31 of Set 8 | hollins
# Processing Record 32 of Set 8 | kedougou
# Processing Record 33 of Set 8 | bay roberts
# Processing Record 34 of Set 8 | gotsu
# Processing Record 35 of Set 8 | marystown
# Processing Record 36 of Set 8 | pervomayskiy
# Processing Record 37 of Set 8 | hualmay
# Processing Record 38 of Set 8 | svetlogorsk
# Processing Record 39 of Set 8 | yafran
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | lambarene
# Processing Record 42 of Set 8 | stillwater
# Processing Record 43 of Set 8 | kirakira
# Processing Record 44 of Set 8 | constantine
# Processing Record 45 of Set 8 | teguise
# Processing Record 46 of Set 8 | saint-joseph
# Processing Record 47 of Set 8 | hit
# Processing Record 48 of Set 8 | santa maria
# Processing Record 49 of Set 8 | atherton
# Processing Record 50 of Set 8 | broome
# Processing Record 1 of Set 9 | vinh
# Processing Record 2 of Set 9 | kaukauna
# Processing Record 3 of Set 9 | tala
# Processing Record 4 of Set 9 | gorontalo
# Processing Record 5 of Set 9 | sri aman
# Processing Record 6 of Set 9 | paraiso
# Processing Record 7 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 8 of Set 9 | gannan
# Processing Record 9 of Set 9 | raga
# Processing Record 10 of Set 9 | poum
# Processing Record 11 of Set 9 | chenghai
# Processing Record 12 of Set 9 | atyrau
# Processing Record 13 of Set 9 | menongue
# Processing Record 14 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 9 | richards bay
# Processing Record 16 of Set 9 | fazendas de almeirim
# Processing Record 17 of Set 9 | lahijan
# Processing Record 18 of Set 9 | ugoofaaru
# Processing Record 19 of Set 9 | uglovka
# Processing Record 20 of Set 9 | guerrero negro
# Processing Record 21 of Set 9 | andros town
# Processing Record 22 of Set 9 | latung
# Processing Record 23 of Set 9 | katsuura
# Processing Record 24 of Set 9 | puerto barrios
# Processing Record 25 of Set 9 | belaya gora
# Processing Record 26 of Set 9 | yemelyanovo
# Processing Record 27 of Set 9 | eyl
# Processing Record 28 of Set 9 | mehamn
# Processing Record 29 of Set 9 | maumere
# Processing Record 30 of Set 9 | ayan
# Processing Record 31 of Set 9 | seymchan
# Processing Record 32 of Set 9 | cozumel
# Processing Record 33 of Set 9 | atambua
# Processing Record 34 of Set 9 | naze
# Processing Record 35 of Set 9 | santa luzia
# Processing Record 36 of Set 9 | viedma
# Processing Record 37 of Set 9 | manggar
# Processing Record 38 of Set 9 | finschhafen
# Processing Record 39 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 9 | thaton
# Processing Record 41 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | baykit
# Processing Record 43 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 9 | chipata
# Processing Record 45 of Set 9 | barbastro
# Processing Record 46 of Set 9 | arman
# Processing Record 47 of Set 9 | kitimat
# Processing Record 48 of Set 9 | manaus
# Processing Record 49 of Set 9 | praya
# Processing Record 50 of Set 9 | khorinsk
# Processing Record 1 of Set 10 | inirida
# Processing Record 2 of Set 10 | tobane
# Processing Record 3 of Set 10 | pasighat
# Processing Record 4 of Set 10 | rio gallegos
# Processing Record 5 of Set 10 | dingle
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | bonavista
# Processing Record 8 of Set 10 | tianjin
# Processing Record 9 of Set 10 | punjai puliyampatti
# Processing Record 10 of Set 10 | bereda
# Processing Record 11 of Set 10 | aras
# Processing Record 12 of Set 10 | yaring
# Processing Record 13 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 10 | birobidzhan
# Processing Record 15 of Set 10 | komsomolskiy
# Processing Record 16 of Set 10 | berlevag
# Processing Record 17 of Set 10 | lata
# Processing Record 18 of Set 10 | rapid valley
# Processing Record 19 of Set 10 | coos bay
# Processing Record 20 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 21 of Set 10 | san rafael
# Processing Record 22 of Set 10 | atasu
# Processing Record 23 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 10 | imeni zhelyabova
# Processing Record 25 of Set 10 | jaciara
# Processing Record 26 of Set 10 | starkville
# Processing Record 27 of Set 10 | makakilo city
# Processing Record 28 of Set 10 | sorland
# Processing Record 29 of Set 10 | quatre cocos
# Processing Record 30 of Set 10 | tokur
# Processing Record 31 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 32 of Set 10 | nacala
# Processing Record 33 of Set 10 | bosobolo
# Processing Record 34 of Set 10 | yar-sale
# Processing Record 35 of Set 10 | tessalit
# Processing Record 36 of Set 10 | zachepylivka
# Processing Record 37 of Set 10 | vao
# Processing Record 38 of Set 10 | labe
# Processing Record 39 of Set 10 | bolshaya dzhalga
# Processing Record 40 of Set 10 | grindavik
# Processing Record 41 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 10 | henties bay
# Processing Record 44 of Set 10 | nizhniy tsasuchey
# Processing Record 45 of Set 10 | jutai
# Processing Record 46 of Set 10 | cabo san lucas
# Processing Record 47 of Set 10 | sobolevo
# Processing Record 48 of Set 10 | pailon
# Processing Record 49 of Set 10 | lianzhou
# Processing Record 50 of Set 10 | durban
# Processing Record 1 of Set 11 | pimentel
# Processing Record 2 of Set 11 | songjianghe
# Processing Record 3 of Set 11 | khanpur
# Processing Record 4 of Set 11 | nombre de dios
# Processing Record 5 of Set 11 | quang ngai
# Processing Record 6 of Set 11 | nador
# Processing Record 7 of Set 11 | college
# Processing Record 8 of Set 11 | yeppoon
# Processing Record 9 of Set 11 | flinders
# Processing Record 10 of Set 11 | bethel
# Processing Record 11 of Set 11 | codrington
# Processing Record 12 of Set 11 | dourbali
# Processing Record 13 of Set 11 | sistranda
# Processing Record 14 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 11 | margate
# Processing Record 16 of Set 11 | bure
# Processing Record 17 of Set 11 | cangzhou
# Processing Record 18 of Set 11 | manta
# Processing Record 19 of Set 11 | sisimiut
# Processing Record 20 of Set 11 | sibolga
# Processing Record 21 of Set 11 | santiago del estero
# Processing Record 22 of Set 11 | plettenberg bay
# Processing Record 23 of Set 11 | husavik
# Processing Record 24 of Set 11 | emba
# Processing Record 25 of Set 11 | igunga
# Processing Record 26 of Set 11 | canberra
# Processing Record 27 of Set 11 | baijiantan
# Processing Record 28 of Set 11 | balkhash
# Processing Record 29 of Set 11 | dubrovnik
# Processing Record 30 of Set 11 | tome-acu
# City not found. Skipping...
# Processing Record 31 of Set 11 | birao
# Processing Record 32 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 33 of Set 11 | roald
# Processing Record 34 of Set 11 | ponca city
# Processing Record 35 of Set 11 | solnechnyy
# Processing Record 36 of Set 11 | idlib
# Processing Record 37 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 11 | namtsy
# Processing Record 39 of Set 11 | lozovo
# Processing Record 40 of Set 11 | lincoln
# Processing Record 41 of Set 11 | bilma
# Processing Record 42 of Set 11 | qui nhon
# Processing Record 43 of Set 11 | hovd
# Processing Record 44 of Set 11 | along
# Processing Record 45 of Set 11 | fort dodge
# Processing Record 46 of Set 11 | las margaritas
# Processing Record 47 of Set 11 | kaeo
# Processing Record 48 of Set 11 | el porvenir
# Processing Record 49 of Set 11 | shingu
# Processing Record 50 of Set 11 | doha
# Processing Record 1 of Set 12 | tigzirt
# Processing Record 2 of Set 12 | borogontsy
# Processing Record 3 of Set 12 | atagay
# Processing Record 4 of Set 12 | amberley
# Processing Record 5 of Set 12 | sarishabari
# Processing Record 6 of Set 12 | soe
# Processing Record 7 of Set 12 | yarada
# Processing Record 8 of Set 12 | seminole
# Processing Record 9 of Set 12 | kegalla
# City not found. Skipping...
# Processing Record 10 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 12 | pincher creek
# Processing Record 12 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 12 | coruripe
# Processing Record 14 of Set 12 | mehran
# Processing Record 15 of Set 12 | elbistan
# Processing Record 16 of Set 12 | korla
# Processing Record 17 of Set 12 | tuatapere
# Processing Record 18 of Set 12 | monchegorsk
# Processing Record 19 of Set 12 | trairi
# Processing Record 20 of Set 12 | morros
# Processing Record 21 of Set 12 | praia da vitoria
# Processing Record 22 of Set 12 | kathmandu
# Processing Record 23 of Set 12 | bilibino
# Processing Record 24 of Set 12 | havoysund
# Processing Record 25 of Set 12 | talcahuano
# Processing Record 26 of Set 12 | caarapo
# Processing Record 27 of Set 12 | fasa
# Processing Record 28 of Set 12 | somotillo
# Processing Record 29 of Set 12 | curup
# Processing Record 30 of Set 12 | nichinan
# Processing Record 31 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 12 | kununurra
# Processing Record 33 of Set 12 | udachnyy
# Processing Record 34 of Set 12 | northam
# Processing Record 35 of Set 12 | mahibadhoo
# Processing Record 36 of Set 12 | toda raisingh
# Processing Record 37 of Set 12 | asau
# Processing Record 38 of Set 12 | uvira
# Processing Record 39 of Set 12 | pelym
# Processing Record 40 of Set 12 | almaznyy
# Processing Record 41 of Set 12 | two rivers
# Processing Record 42 of Set 12 | umm lajj
# Processing Record 43 of Set 12 | port macquarie
# Processing Record 44 of Set 12 | verkhnyaya toyma
# Processing Record 45 of Set 12 | itaituba
# Processing Record 46 of Set 12 | martin
# Processing Record 47 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 12 | dehloran
# Processing Record 49 of Set 12 | papetoai
# Processing Record 50 of Set 12 | sur
# Processing Record 1 of Set 13 | shaoyang
# Processing Record 2 of Set 13 | surgana
# Processing Record 3 of Set 13 | chaohu
# Processing Record 4 of Set 13 | crib point
# Processing Record 5 of Set 13 | erechim
# Processing Record 6 of Set 13 | akhmeta
# Processing Record 7 of Set 13 | onalaska
# Processing Record 8 of Set 13 | kampong thum
# Processing Record 9 of Set 13 | vostok
# Processing Record 10 of Set 13 | businga
# Processing Record 11 of Set 13 | sambava
# Processing Record 12 of Set 13 | plerin
# Processing Record 13 of Set 13 | nynashamn
# Processing Record 14 of Set 13 | kahului
# Processing Record 15 of Set 13 | gedo
# Processing Record 16 of Set 13 | chumikan
# Processing Record 17 of Set 13 | yenagoa
# Processing Record 18 of Set 13 | baft
# Processing Record 19 of Set 13 | tagusao
# Processing Record 20 of Set 13 | salalah
# Processing Record 21 of Set 13 | buon me thuot
# City not found. Skipping...
# Processing Record 22 of Set 13 | seydi
# Processing Record 23 of Set 13 | eureka
# Processing Record 24 of Set 13 | cap-aux-meules
# Processing Record 25 of Set 13 | santo augusto
# Processing Record 26 of Set 13 | imbituba
# Processing Record 27 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 13 | tambopata
# Processing Record 29 of Set 13 | wanning
# Processing Record 30 of Set 13 | nayoro
# Processing Record 31 of Set 13 | ixtapa
# Processing Record 32 of Set 13 | louis trichardt
# Processing Record 33 of Set 13 | bonga
# Processing Record 34 of Set 13 | motygino
# Processing Record 35 of Set 13 | shelburne
# Processing Record 36 of Set 13 | tanabe
# Processing Record 37 of Set 13 | mao
# Processing Record 38 of Set 13 | lishui
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | rocha
# Processing Record 41 of Set 13 | polovinnoye
# Processing Record 42 of Set 13 | nhulunbuy
# Processing Record 43 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 13 | sabzevar
# Processing Record 45 of Set 13 | marovoay
# Processing Record 46 of Set 13 | arys
# Processing Record 47 of Set 13 | lasa
# Processing Record 48 of Set 13 | leningradskiy
# Processing Record 49 of Set 13 | presidencia roque saenz pena
# Processing Record 50 of Set 13 | vanavara
# Processing Record 1 of Set 14 | gelemso
# Processing Record 2 of Set 14 | the valley
# Processing Record 3 of Set 14 | mahanoro
# Processing Record 4 of Set 14 | taoudenni
# Processing Record 5 of Set 14 | macau
# Processing Record 6 of Set 14 | swan hill
# Processing Record 7 of Set 14 | jalu
# Processing Record 8 of Set 14 | cuamba
# Processing Record 9 of Set 14 | luderitz
# Processing Record 10 of Set 14 | tumarbong
# Processing Record 11 of Set 14 | cockburn town
# Processing Record 12 of Set 14 | pangnirtung
# Processing Record 13 of Set 14 | semnan
# Processing Record 14 of Set 14 | shache
# Processing Record 15 of Set 14 | ozinki
# Processing Record 16 of Set 14 | preobrazheniye
# Processing Record 17 of Set 14 | sao gabriel da cachoeira
# Processing Record 18 of Set 14 | orlik
# Processing Record 19 of Set 14 | coihaique
# Processing Record 20 of Set 14 | deputatskiy
# Processing Record 21 of Set 14 | xining
# Processing Record 22 of Set 14 | gogrial
# Processing Record 23 of Set 14 | minot
# Processing Record 24 of Set 14 | marsa matruh
# Processing Record 25 of Set 14 | gabu
# Processing Record 26 of Set 14 | hushitai
# Processing Record 27 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 14 | altay
# Processing Record 29 of Set 14 | necochea
# Processing Record 30 of Set 14 | kavaratti
# Processing Record 31 of Set 14 | houma
# Processing Record 32 of Set 14 | hokitika
# Processing Record 33 of Set 14 | noboribetsu
# Processing Record 34 of Set 14 | raudeberg
# Processing Record 35 of Set 14 | linjiang
# Processing Record 36 of Set 14 | rafaela
# Processing Record 37 of Set 14 | satipo
# Processing Record 38 of Set 14 | inta
# Processing Record 39 of Set 14 | kuytun
# Processing Record 40 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 14 | ust-omchug
# Processing Record 42 of Set 14 | luena
# Processing Record 43 of Set 14 | gubkinskiy
# Processing Record 44 of Set 14 | kingsville
# Processing Record 45 of Set 14 | komatipoort
# Processing Record 46 of Set 14 | aksarka
# Processing Record 47 of Set 14 | waingapu
# Processing Record 48 of Set 14 | cochrane
# Processing Record 49 of Set 14 | kuybysheve
# Processing Record 50 of Set 14 | altamira
# Processing Record 1 of Set 15 | ilula
# Processing Record 2 of Set 15 | raymondville
# Processing Record 3 of Set 15 | maltahohe
# Processing Record 4 of Set 15 | valdivia
# Processing Record 5 of Set 15 | luzhou
# Processing Record 6 of Set 15 | dwarka
# Processing Record 7 of Set 15 | kidal
# Processing Record 8 of Set 15 | salou
# Processing Record 9 of Set 15 | richard toll
# City not found. Skipping...
# Processing Record 10 of Set 15 | ekhabi
# Processing Record 11 of Set 15 | innisfail
# Processing Record 12 of Set 15 | takaka
# Processing Record 13 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 15 | jacareacanga
# Processing Record 15 of Set 15 | bulanash
# Processing Record 16 of Set 15 | diamantino
# Processing Record 17 of Set 15 | grand gaube
# Processing Record 18 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 15 | sacramento
# Processing Record 20 of Set 15 | abapo
# Processing Record 21 of Set 15 | yabelo
# Processing Record 22 of Set 15 | anori
# Processing Record 23 of Set 15 | doka
# Processing Record 24 of Set 15 | safford
# Processing Record 25 of Set 15 | kasiri
# Processing Record 26 of Set 15 | port-cartier
# Processing Record 27 of Set 15 | dicabisagan
# Processing Record 28 of Set 15 | coahuayana
# Processing Record 29 of Set 15 | garmsar
# Processing Record 30 of Set 15 | yaguajay
# Processing Record 31 of Set 15 | muisne
# Processing Record 32 of Set 15 | mount isa
# Processing Record 33 of Set 15 | formosa do rio preto
# Processing Record 34 of Set 15 | penzance
# Processing Record 35 of Set 15 | lokosovo
# Processing Record 36 of Set 15 | arica
# Processing Record 37 of Set 15 | matadi
# Processing Record 38 of Set 15 | bathsheba
# Processing Record 39 of Set 15 | zonguldak
# Processing Record 40 of Set 15 | safaga
# Processing Record 41 of Set 15 | esso
# Processing Record 42 of Set 15 | leshukonskoye
# Processing Record 43 of Set 15 | inhambane
# Processing Record 44 of Set 15 | eydhafushi
# Processing Record 45 of Set 15 | umm kaddadah
# Processing Record 46 of Set 15 | vredendal
# Processing Record 47 of Set 15 | kiknur
# Processing Record 48 of Set 15 | nizhniy odes
# Processing Record 49 of Set 15 | asfi
# Processing Record 50 of Set 15 | abha
# Processing Record 1 of Set 16 | morondava
# Processing Record 2 of Set 16 | dunedin
# Processing Record 3 of Set 16 | yunjinghong
# City not found. Skipping...
# Processing Record 4 of Set 16 | ewa beach
# Processing Record 5 of Set 16 | macea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed","Current Description"]]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Iqaluit      CA  63.75  -68.51     48.20        76          40
# 1       Sarahan      IN  31.52   77.80     63.54        76          54
# 2  Puerto Ayora      EC  -0.74  -90.35     75.20        60          40
# 3     Saskylakh      RU  71.92  114.08     40.93        83           0
# 4  Port Hedland      AU -20.32  118.57     66.20        55           0
# 5      Coquimbo      CL -29.95  -71.34     55.40        66          90
# 6     Busselton      AU -33.65  115.33     45.00        77           1
# 7  Punta Arenas      CL -53.15  -70.92     37.40        55          40
# 8        Barrow      US  71.29 -156.79     37.40       100          90
# 9          Nome      US  64.50 -165.41     51.80        81          90
#
#    Wind Speed Current Description
# 0        3.36    scattered clouds
# 1        1.45       broken clouds
# 2       14.99    scattered clouds
# 3        8.16           clear sky
# 4        8.05           clear sky
# 5       18.34     overcast clouds
# 6        4.61           clear sky
# 7       28.86    scattered clouds
# 8       14.99                mist
# 9        9.17     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
